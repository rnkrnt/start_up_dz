# %% [markdown]
# # Завдання 1

# %% [markdown]
#  Для заданого статистичного розподілу побудуємо гістограму частот.

# %% [markdown]
# ![Полігон відносних частот](Пол_відн_част.png "Полігон відносних частот")

# %% [markdown]
# За формою гістограми частот можемо припустити, що ознака $Х$ має нормальний закон розподілу. Отже, висуваємо нульову гіпотезу $Н_0$: ознака $Х$ має нормальний закон розподілу ймовірностей. Для перевірки правильності $Н_0$ використаємо критерій узгодженості Пірсона.

# %% [markdown]
# Спочатку обчислимо вибіркове середнє $\bar{x^*}$ середнє квадратичне відхилення вибірки $\sigma^*$. Для цього перетворимо інтервальний статистичний розподіл вибірки на дискретний:

# %% [markdown]
# \begin{array}{|c|c|}
#   \hline
#   x_i & 12 & 36 & 60 & 84 & 108 & 132 & 156 & 180 & 204 &   \\
#   \hline
#   n_i   & 1 & 2 & 4 & 6 & 12 & 16 & 6 & 2 & 1 & n=50 \\
#   \hline
#   w_i   & 0.02 & 0.04 & 0.08 & 0.12 & 0.24 & 0.32 & 0.12 & 0.04 & 0.02 & 1  \\
#   \hline
#  \end{array}

# %% [markdown]
# Отже:

# %% [markdown]
# $$
# \bar{x^*} = \frac{1 \cdot 12 + 2 \cdot 36 + 4 \cdot 60 + 6 \cdot 84 + 12 \cdot 108 + 16 \cdot 132  + 6 \cdot 156  +}{50}
# $$

# %% [markdown]
# $$
# \frac{+ 2 \cdot 180  + 1 \cdot 204}{}=114.72
# $$

# %% [markdown]
# $$
# \sigma^2 = \frac{1^2 \cdot 12 + 2^2 \cdot 36 + 4^2 \cdot 60 + 6^2 \cdot 84 + 12^2 \cdot 108 + 16^2 \cdot 132  + 6^2 \cdot 156 +}{50}
# $$

# %% [markdown]
# $$
# \frac{+ 2^2 \cdot 180  + 1^2 \cdot 204}{}-114.72^2 = 1452.44
# $$

# %% [markdown]
# $$
# \sigma^* = \sqrt{1452.44} \approx 38.11
# $$

# %% [markdown]
# Знайдемо нормовані інтервали $(z_i;z_{i+1}]$, враховуючи, що вибіркове середнє $\bar{x^*}=114.72$ і cереднє квадратичне відхилення вибірки $\sigma^*=38.11$. Для цього складемо розрахункову таблицю (лівий кінець першого інтервалу вважаємо рівним $-\propto$, а правий кінець останнього інтервалу – рівним $\propto$ .

# %% [markdown]
# \begin{array}{|c|c|}
#   \hline
#   i & x_i & x_{i+1} & x_{i}-\bar{x^*} & x_{i+1}-\bar{x^*} & z_i=\frac{x_{i}-\bar{x^*}}{\sigma^*} & z_{i+1}=\frac{x_{i+1}-\bar{x^*}}{\sigma^*}    \\
#   \hline
#   1   & 0 & 24 & -114.72 & -90.72 & -\propto & -2.38  \\
#   \hline
#   2   & 24 & 48 & -90.72 & -66.72 & -2.38 & -1.75    \\
#   \hline
#   3   & 48 & 72 & -66.72 & -42.72 & -1.75 & -1.12    \\
#   \hline
#   4   & 72 & 96 & -42.72 & -18.72 & -1.12 & -0.49    \\
#   \hline
#   5   & 96 & 120 & -18.72 & 5.28 & -0.49 & 0.14    \\
#   \hline
#   6   & 120 & 144 & 5.28 & 29.28 &  0.14 & 0.77    \\
#   \hline
#   7   & 144 & 168 & 29.28 & 53.28 & 0.77 & 1.40    \\
#   \hline
#   8   & 168 & 192 & 53.28 & 77.28 & 1.40 & 2.03    \\
#   \hline
#   9   & 192 & 216 & 77.28 & 101.28 & 2.03 & \propto    \\
#   \hline
#  \end{array}

# %% [markdown]
# Визначимо теоретичні ймовірності $P_i$ і теоретичні частоти $ n_i'$:

# %% [markdown]
# \begin{array}{|c|c|}
#   \hline
#   i & z_i & z_{i+1} & Ф(z_i) & Ф(z_{i+1}) & P_i=Ф(z_{i+1})-Ф(z_i) &  n_i'=n \cdot P_i   \\
#   \hline
#   1   & -\propto & -2.38 & -0.5 & -0.4913 & 0.009 & 0.435 \\
#   \hline
#   2   &  -2.38 & -1.75  & -0.4913 & -0.4599 & 0.031 & 1.57 \\
#   \hline
#   3   &  -1.75 & -1.12  & -0.4599 & -0.3686 & 0.091 & 4.565 \\
#   \hline
#   4   &  -1.12 & -0.49  & -0.3686 & -0.1879 & 0.181 & 9.035 \\
#   \hline
#   5   &  -0.49 & 0.14   & -0.1879 & 0.0557 & 0.244 & 12.18 \\
#   \hline
#   6   &   0.14 & 0.77   & 0.0557  & 0.2794 & 0.224 & 11.185 \\
#   \hline
#   7   &  0.77 & 1.40    & 0.2794  & 0.4192 & 0.140 & 6.99 \\
#   \hline
#   8   &  1.40 & 2.03    & 0.4192  & 0.4788 & 0.060 & 2.98 \\
#   \hline
#   9   &  2.03 & \propto & 0.4788  & 0.5 & 0.021 & 1.06 \\
#   \hline
#    \sum  & -  & -  & - & - & 1 & 50  \\
#   \hline
#  \end{array}

# %% [markdown]
# Порівняємо емпіричні та теоретичні частоти, використовуючи критерій
# Пірсона. Для цього обчислимо спочатку спостережуване значення критерію
# Пірсона за допомогою розрахункової таблиці.

# %% [markdown]
# \begin{array}{|c|c|}
#   \hline
#   i & n_i & n_i' & n_i-n_i' & (n_i-n_i')^2 & \frac{(n_i-n_i')^2}{n_i'} &  n_i^2  & \frac{n_i^2}{n_i'} \\
#   \hline
#   1   & 1 & 0.435 & 0.565 & 0.319 & 0.734 & 1 & 2.299 \\
#   \hline
#   2   &  2 & 1.57  & 0.43 & 0.185 & 0.118 & 4 & 2.548  \\
#   \hline
#   3   &  4 & 4.565  & -0.565 & 0.319 & 0.070 & 16 & 3.505  \\
#   \hline
#   4   &  6 & 9.035  & -3.035 & 9.211 & 1.020 & 36 & 3.985 \\
#   \hline
#   5   &  12 & 12.18   & -0.18 & 0.032 & 0.003 & 144 & 11.823 \\
#   \hline
#   6   &  16 & 11.185   & 4.815  & 23.184 & 2.073 & 256 & 22.888 \\
#   \hline
#   7   &  6  & 6.99    & -0.99  & 0.980 & 0.140 & 36 & 5.150 \\
#   \hline
#   8   &  2  & 2.98    & -0.98  & 0.960 & 0.322 & 4 & 1.342 \\
#   \hline
#   9   &  1 & 1.06     & -0.06  & 0.004 & 0.003 & 1 & 0.943 \\
#   \hline
#    \sum  & 50  & 50  & - & - & X_{спост}^2 = 4.482 & 4.482 & 54.482  \\
#   \hline
#  \end{array}

# %% [markdown]
# Перевірка: $ X_{спост}^2 = \sum_{i=1}^{m} \frac{n_i^2}{n_i'} - n_i$. Оскільки $54.482-50=4.482=X_{спост}^2$, то обчислення  проведено правильно.

# %% [markdown]
# За таблицею критичних точок розподілу $X^2$ при рівні значущості, $\alpha = 0.01$ і кількості ступенів вільності:

# %% [markdown]
# $$
# k = s - 3 = 9 - 3 = 6
# $$

# %% [markdown]
# знайдемо критичну точку правосторонньої критичної області:

# %% [markdown]
# $$
# X_{крит}^2(0.01;6) = 16.81
# $$

# %% [markdown]
# Оскільки $X_{спост}^2<X_{крит}^2$, гіпотезу про нормальний розподіл генеральної
# сукупності не відхиляємо. Тобто, емпіричні та теоретичні частоти відрізняються несуттєво.

# %% [markdown]
# # Завдання 2

# %% [markdown]
# Щільність рівномірного розподілу $
# f(x)=\frac{1}{b-a} $. Отже, потрібно визначити проміжок $(a, b)$ зміни випадкової величини. Складемо систему рівнянь:

# %% [markdown]
#   \begin{cases}
#     \int\limits_3^b \frac{1}{b-a}dx = 0.4;    \\
#     \int\limits_a^b \frac{x}{b-a}dx = 2;      \\
#   \end{cases}
#
#
#
#   \begin{cases}
#     \frac{b-3}{b-a} = 0.4;    \\
#     \frac{a+b}{2} = 2;        \\
#   \end{cases}
#
#
#
#   \begin{cases}
#     0.6b +0.4a = 3;    \\
#     b = 4-a;        \\
#   \end{cases}
#
# $$
#   b=7; a=-3
# $$

# %% [markdown]
# Отже щільність розподілу:

# %% [markdown]
# $$
# f(x)  =
#   \begin{cases}
#     0   ,  &  якщо \quad       x \leq -3    \\
#     0.1 ,  &  якщо \quad -3  < x \leq  7    \\
#     0   ,  &  якщо \quad       x  >    8    \\
#   \end{cases}
# \
# $$

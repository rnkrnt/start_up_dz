# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Normalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import mae

# %%
np.random.seed(101)

# %%
x = np.linspace(147, 210, 300)
y = np.linspace(40, 110, 300)

# %%
x += np.random.uniform(-10, 10, 300)
y += np.random.uniform(-3, 3, 300)

# %%
plt.scatter(x, y)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Data')
plt.show()

# %%
normalizer_layer = Normalization(input_shape=(1,), axis=None)
normalizer_layer.adapt(x)

model = Sequential([
    normalizer_layer,
    Dense(1)
])
model.compile(optimizer=Adam(learning_rate=0.1), loss=mae)
model_saved = model.fit(x, y, epochs=130, validation_split=0.2)
# Out:
# Epoch 1/130
# 8/8 [==============================] - 1s 25ms/step - loss: 67.2320 - val_loss: 104.3523
# Epoch 2/130
# 8/8 [==============================] - 0s 5ms/step - loss: 66.2015 - val_loss: 104.5186
# Epoch 3/130
# 8/8 [==============================] - 0s 5ms/step - loss: 65.1478 - val_loss: 104.6141
# Epoch 4/130
# 8/8 [==============================] - 0s 5ms/step - loss: 64.1113 - val_loss: 104.7456
# Epoch 5/130
# 8/8 [==============================] - 0s 5ms/step - loss: 63.0901 - val_loss: 104.9169
# Epoch 6/130
# 8/8 [==============================] - 0s 5ms/step - loss: 62.0536 - val_loss: 105.0708
# Epoch 7/130
# 8/8 [==============================] - 0s 5ms/step - loss: 61.0261 - val_loss: 105.2215
# Epoch 8/130
# 8/8 [==============================] - 0s 5ms/step - loss: 59.9803 - val_loss: 105.3111
# Epoch 9/130
# 8/8 [==============================] - 0s 5ms/step - loss: 58.9474 - val_loss: 105.4146
# Epoch 10/130
# ...

# %%
plt.plot(model_saved.history['loss'],label='Train_loss')
plt.xlabel('Epochs')
plt.ylabel('Train_loss')
plt.title('Train losses over epochs')
plt.legend()

# %%
plt.plot(model_saved.history['val_loss'],label='Val_loss')
plt.xlabel('Epochs')
plt.ylabel('Val_loss')
plt.title('Validation losses over epochs')
plt.legend()

# %%
plt.scatter(x, y, label ='Original data')
plt.plot(x, model.predict(x), 'r', label ='Fitted line')
plt.title('Linear Regression Result')
plt.legend()
plt.show()
# Out:
# 10/10 [==============================] - 0s 901us/step
